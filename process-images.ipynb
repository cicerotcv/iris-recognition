# %%
import cv2
import matplotlib.pyplot as plt

# %%
SOURCE = "./images-tutorial/"
DEST = "./"
img = "0002/0002_000.bmp"

# %%
cvimg = cv2.imread(img)
gray = cv2.cvtColor(cvimg, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
after_eq = cv2.equalizeHist(gray)
plt.imshow(gray, cmap='gray')
